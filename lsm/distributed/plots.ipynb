# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from tifffile import imread

# %%
imname = ['chunk_32.tiff', 'chunk_64.tiff', 'chunk_128.tiff', 'chunk_256.tiff']
root_dir = '/om2/user/ckapoor/lsm-segmentation/model_analysis/stitching/cellpose_seg/'

# %%
nuclei = {}
for n in imname:
    impath = os.path.join(root_dir, n)
    im = imread(impath)
    nuclei
    nuclei.append(len(np.unique(im)))

# %%
chunk_sizes = [32, 64, 128, 256]

# %%
nuclei
# Out:
# [1797, 1471, 1373, 1180]

# %%
data = pd.DataFrame([nuclei], columns=['Chunk 32', 'Chunk 64', 'Chunk 128', 'Chunk 256'])

# %%
def box_plot():
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=chunk_sizes, y=f'# Nuclei', data=data)
    plt.title(f"Distribution of Nuclei Count Across Chunk Sizes")
    plt.ylabel(self.metric_name)
    plt.xlabel(self.var_name)

    plt.show()

# %%
data = [1, 2, 3, 4]

# Convert list to a DataFrame for better customization
df = pd.DataFrame(data, columns=['Values'])

# Create the box plot with labels
sns.boxplot(data=df)

# Adding a title and labels
plt.title('Box Plot of List Entries')
plt.ylabel('Values')

# Display the plot
plt.show()

# %%
data = [1, 2, 3, 4]

df = pd.DataFrame(data, columns=['Values'])

sns.pointplot(x=df.index, y='Values', data=df)

plt.title('Point Plot of List Entries')
plt.xlabel('Index')
plt.ylabel('Values')

plt.show()
